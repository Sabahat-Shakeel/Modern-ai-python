# %% [markdown]
# # Python website
#
#    - Home Page
#      - PIAIC Student ID
#
#    - About Page
#     - Small detail about PIAIC
#    - Contact Page
#      - Email address

# %%
import streamlit as st

st.set_page_config(page_title="PIAIC Student Card", layout="centered")

st.sidebar.write("BUILD BY SABAHAT SHAKEEL")
menu = st.sidebar.radio("", ["Home", "About", "Contact"])


if menu == "Home":
    st.title("PIAIC Student")
    st.subheader("Batch 66")


    with st.container():
   
        col1, col2 = st.columns([3, 1])  # Divide into 3:1 ratio
        
        with col1:
            st.markdown("**Name:** Sabahat Shakeel")
            st.markdown("**Roll No:** PIAIC12345")
            st.markdown("**Campus:** Scout Boys Auditorium")
            st.markdown("**Day/Times:** Saturday 2pm to 6pm")
            st.markdown("**City:** Karachi")
        
      
        with col2:
          
            st.image("sabahat.jpg", width=100)

  
    st.write("---") 
  
    st.write("### Skills & Expertise")
    st.write("- *Next.js*")
    st.write("- *TypeScript*")
    st.write("- *TailwindCSS*")
    st.write("- *Custom CSS*")
    st.write(" ")

    st.header("Goal")
    st.header("AI Developer")
    st.write("*An AI Developer crafts intelligent solutions by leveraging data, algorithms, and cutting-edge technologies to build systems that learn, adapt, and solve real-world problems.* ")

elif menu == "About":
    st.title("About PIAIC")
    st.write("""
    The Presidential Initiative for Artificial Intelligence and Computing (PIAIC) is 
    an initiative to revolutionize Pakistan by preparing a generation of AI and computing 
    experts.
    """)

elif menu == "Contact":
    st.title("Contact Us")
    st.write("You can reach out via email at: **support@piaic.org**")
